# %%
filename='rotowire.tar.bz2'
import tarfile
tar= tarfile.open(filename,mode='r')
tar.extractall()
tar.close()

# %%
# %cd

# %%
# %cd /content/drive/My Drive/Colab Notebooks/project_rotowire
# Out:
# /content/drive/My Drive/Colab Notebooks/project_rotowire

# %%
# !python settings.py

# %%
# !python preprocessing.py

# %%
# !python dataprepare.py
# Out:
# Read train data
# Read 3398 box score summary
# Embedding size of (r.t, r.e, r.m) and summary:
# (43, 712, 216), 10002
# Read valid data
# Read 727 box score summary
# Embedding size of (r.t, r.e, r.m) and summary:
# (43, 691, 211), 5704
# Read test data
# Read 728 box score summary
# Embedding size of (r.t, r.e, r.m) and summary:
# (43, 701, 213), 5821

# %%
# !python model.py

# %%
# !python util.py

# %%
# !python train.py
# Out:
# Start Training
# ---------------
# Parameter Settings:
# embedding_size = 600
# learning_rate = 0.01
# batch_size = 1
# get_loss = 1
# encoder_style = HierarchicalRNN
# decoder_style = HierarchicalRNN
# save_model = 5
# output_file = pretrain_copy_ms5
# to_copy = False
# copy_player = False
# grad_clip = 5
# pretrain = None
# iter_num = 22000
# layer_depth = 2
# epoch_time = 220
# max_length = 800
# max_sentence = None
# ---------------
# Read train data
# Read 3398 box score summary
# Embedding size of (r.t, r.e, r.m) and summary:
# (43, 712, 216), 10002
# Not use Pretrain Model
# Epoch #1
# train.py:473: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   grad_clip)
# Time 0m 39s, iter 1, Seq_len:171, avg loss = 9.2129
# Time 1m 16s, iter 2, Seq_len:161, avg loss = 8.2977
# Time 3m 39s, iter 3, Seq_len:177, avg loss = 15.6321
# Time 4m 19s, iter 4, Seq_len:162, avg loss = 12.7478
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !python small_evaluate.py
# Out:
# Start Evaluating
# None
# Read train data
# Read 3398 box score summary
# Embedding size of (r.t, r.e, r.m) and summary:
# (43, 712, 216), 10002
# Read valid data
# Read 727 box score summary
# Embedding size of (r.t, r.e, r.m) and summary:
# (43, 691, 211), 5704
# Generate Summary 1:
# ...

# %%
# !python BLEU.py

# %%
import nltk

reference = ["Louis Williams has been a bright spot for the injury - riddled Los Angeles Lakers , although his scoring outbursts are not translating into wins for the team at the moment . <BLK> In five of the six games that the Lakers have lost during their rough streak , Williams has scored at least 24 points , adding another 24 - point game against the Knicks . <BLK> It actually falls on the lower end of the scoring spectrum for Williams in his increased minutes , as three of those games he scored at least 30 points . <BLK> As for the Knicks , Kristaps Porzingis played both ends of the floor effectively , racking up 26 points , to go along with 12 rebounds , two assists and seven blocks on 8 - of - 15 shooting . <BLK> While Carmelo Anthony only managed 13 points on 16 shots , Derrick Rose ( back ) bailed him out with one of his best performances in a Knicks uniform , scoring 25 points on 12 - of - 16 shooting",
